# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 8</font>
#
# ## Download: http://github.com/dsacademybr

# %% [markdown]
# ****** Este Jupyter Notebook foi atualizado para a versão 3.6.1 da Linguagem Python em 05/06/2017 ******

# %% [markdown]
# ### Bokeh

# %% [markdown]
# ### Caso o Bokeh não esteja instalado, executar:

# %%
# !pip install bokeh -U
# Out:
# Requirement already up-to-date: bokeh in /Users/dmpm/anaconda/lib/python3.6/site-packages

# %%
# Importando o módulo Bokeh
import bokeh

# %%
# Usando output_file para gravar as visualizações
from bokeh.plotting import figure, output_file, show

# Usando output_notebook para visualizar no iPython Notebook
from bokeh.charts import Bar, output_notebook, show

# %%
# Output 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e21d08f3-beae-47a1-835b-ad2a75b6daa6">Loading BokehJS ...</span>
#     </div>

# %%
# Arquivo gerado pela visualização
output_file("Bokeh-Grafico-Interativo.html")

# %%
p = figure()

# %%
type(p)
# Out:
# bokeh.plotting.figure.Figure

# %%
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width = 2)
# Out:
# GlyphRenderer(id='cb0a08a0-b90f-4790-b3d4-ecbb2015b91c', ...)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3aefdaa6-02a7-4b4b-9004-43595599aa0a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3aefdaa6-02a7-4b4b-9004-43595599aa0a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3aefdaa6-02a7-4b4b-9004-43595599aa0a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3aefdaa6-02a7-4b4b-9004-43595599aa0a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"24bbcc22-9054-412e-8522-edf41e6cd2fe":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7841517b-9917-4187-b345-74411bee943b","type":"PanTool"},{"id":"a9839467-093e-4b67-a209-63d033fb5b85","type":"WheelZoomTool"},{"id":"596ab400-23e6-4340-a9cb-a109cc85bc49","type":"BoxZoomTool"},{"id":"e730f722-6fcb-4fce-bc85-7ee70a304e8d","type":"SaveTool"},{"id":"d62948bd-58fa-414f-826b-6a7d619c02e1","type":"ResetTool"},{"id":"5586bd99-89b7-4483-9510-e48bd0d5ab27","type":"HelpTool"}]},"id":"f6bf0697-a51f-4161-b220-110d80a41075","type":"Toolbar"},{"attributes":{},"id":"626833ad-fa4d-4ea4-9896-f50d99112bce","type":"ToolEvents"},{"attributes":{"formatter":{"id":"ba774472-cdda-4f6e-b9df-44484e26b3f2","type":"BasicTickFormatter"},"plot":{"id":"cba122ca-5890-4570-9f6e-7dbd7730877e","subtype":"Figure","type":"Plot"},"ticker":{"id":"63fbde3c-fab7-4804-8179-8f390cc27f6a","type":"BasicTicker"}},"id":"b9ed9fa3-bbaf-4d75-bf76-9c8cce96abec","type":"LinearAxis"},{"attributes":{"overlay":{"id":"99ebc94c-e159-4d75-9c7b-4f4b8d46da13","type":"BoxAnnotation"},"plot":{"id":"cba122ca-5890-4570-9f6e-7dbd7730877e","subtype":"Figure","type":"Plot"}},"id":"596ab400-23e6-4340-a9cb-a109cc85bc49","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"8c9790e1-ef80-4356-a92b-c21bc11958ba","type":"DataRange1d"},{"attributes":{"callback":null},"id":"697acf27-c60e-4c08-99c2-72108481e59e","type":"DataRange1d"},{"attributes":{"formatter":{"id":"94954cf9-d8e8-4d96-969c-1b406a727255","type":"BasicTickFormatter"},"plot":{"id":"cba122ca-5890-4570-9f6e-7dbd7730877e","subtype":"Figure","type":"Plot"},"ticker":{"id":"e6102e9c-aded-4f3f-8503-d331a0c45389","type":"BasicTicker"}},"id":"be42399e-7e0e-4d69-bd29-39674dccf9a9","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b1b71af8-127b-40b3-bd91-c5599b3719ad","type":"Line"},{"attributes":{},"id":"e6102e9c-aded-4f3f-8503-d331a0c45389","type":"BasicTicker"},{"attributes":{},"id":"63fbde3c-fab7-4804-8179-8f390cc27f6a","type":"BasicTicker"},{"attributes":{"below":[{"id":"be42399e-7e0e-4d69-bd29-39674dccf9a9","type":"LinearAxis"}],"left":[{"id":"b9ed9fa3-bbaf-4d75-bf76-9c8cce96abec","type":"LinearAxis"}],"renderers":[{"id":"be42399e-7e0e-4d69-bd29-39674dccf9a9","type":"LinearAxis"},{"id":"20231398-b136-46fc-8ec3-49be8f98613a","type":"Grid"},{"id":"b9ed9fa3-bbaf-4d75-bf76-9c8cce96abec","type":"LinearAxis"},{"id":"241243ae-623a-4f26-8a6d-f48deb4b3966","type":"Grid"},{"id":"99ebc94c-e159-4d75-9c7b-4f4b8d46da13","type":"BoxAnnotation"},{"id":"cb0a08a0-b90f-4790-b3d4-ecbb2015b91c","type":"GlyphRenderer"}],"title":{"id":"e5e724af-693a-42f4-9bf2-ecf579fa9d3c","type":"Title"},"tool_events":{"id":"626833ad-fa4d-4ea4-9896-f50d99112bce","type":"ToolEvents"},"toolbar":{"id":"f6bf0697-a51f-4161-b220-110d80a41075","type":"Toolbar"},"x_range":{"id":"697acf27-c60e-4c08-99c2-72108481e59e","type":"DataRange1d"},"y_range":{"id":"8c9790e1-ef80-4356-a92b-c21bc11958ba","type":"DataRange1d"}},"id":"cba122ca-5890-4570-9f6e-7dbd7730877e","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"e5e724af-693a-42f4-9bf2-ecf579fa9d3c","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"fda763da-444a-493b-9abc-e1338e09c2b4","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"99ebc94c-e159-4d75-9c7b-4f4b8d46da13","type":"BoxAnnotation"},{"attributes":{},"id":"94954cf9-d8e8-4d96-969c-1b406a727255","type":"BasicTickFormatter"},{"attributes":{},"id":"ba774472-cdda-4f6e-b9df-44484e26b3f2","type":"BasicTic ...

# %%
# Usando output_notebook para visualizar no iPython Notebook
from bokeh.charts import Bar, output_notebook, show

# %%
# Preparando dados
data = {"y": [1, 2, 3, 4, 5]}

# %%
# Output 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="470cb0db-d6d7-467e-a5d5-083c58290b40">Loading BokehJS ...</span>
#     </div>

# %%
# Criando um novo gráfico
gr = Bar(data, title = "Gráfico Bokeh", xlabel = 'x', ylabel = 'valores', 
         width = 400, height = 400)

# %%
# Mostrando os resultados
show(gr)
# Out:
# /Users/dmpm/anaconda/lib/python3.6/site-packages/bokeh/core/json_encoder.py:73: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   if pd and isinstance(obj, pd.tslib.Timestamp):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8ecc301c-85ff-45b9-bd57-a172e3a4133e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8ecc301c-85ff-45b9-bd57-a172e3a4133e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8ecc301c-85ff-45b9-bd57-a172e3a4133e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8ecc301c-85ff-45b9-bd57-a172e3a4133e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3e2013f6-137e-4ff9-98fb-50e64b6ab0e3":{"roots":{"references":[{"attributes":{"label":{"value":"1"},"renderers":[{"id":"1b46c9c2-6c71-4ece-9e73-711145a580a3","type":"GlyphRenderer"}]},"id":"41b46182-9f23-4a18-835a-ea55186541a1","type":"LegendItem"},{"attributes":{},"id":"08a3490c-0701-416a-ac12-c28f9e9ba82e","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":2}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"index":[2],"label":[{"index":2}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2"],"y":[1.5]}},"id":"8eb3d423-7b78-4267-801b-bb87ae3136ae","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8eb3d423-7b78-4267-801b-bb87ae3136ae","type":"ColumnDataSource"},"glyph":{"id":"d4b009cf-e3ad-4aab-b4d8-dbb2b700f94a","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ffd97e02-a427-47f2-bed5-64f61d21c542","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":3}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"index":[3],"label":[{"index":3}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["3"],"y":[2.0]}},"id":"cc7fe5c9-6c55-408e-a508-4f08437be968","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["0","1","2","3","4"]},"id":"045eff29-8ccf-4aac-bbe7-d5415fd27e14","type":"FactorRange"},{"attributes":{},"id":"e95d3b17-aa9f-4762-ac9f-08413e219a6b","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"ffd3de92-1e68-417e-a8e3-2fccd64961d0","type":"GlyphRenderer"}]},"id":"5e2b3e09-e7de-473c-b4be-9494d90c5090","type":"LegendItem"},{"attributes":{},"id":"c43f69e4-66f4-428e-ab12-c09cf2241cba","type":"CategoricalTickFormatter"},{"attributes":{"label":{"value":"3"},"renderers":[{"id":"0cdfa5d1-5a93-43b6-957c-c0ec435de61d","type":"GlyphRenderer"}]},"id":"7a3899ee-a926-462b-b802-1d2c41f73051","type":"LegendItem"},{"attributes":{"below":[{"id":"7b1cd4d9-0f01-497d-9fcf-a12c59c83f55","type":"CategoricalAxis"}],"css_classes":null,"height":400,"left":[{"id":"d537e190-0390-4f12-ba99-4f3936ec9abc","type":"LinearAxis"}],"renderers":[{"id":"09056212-77ba-4d53-926e-85f95915607b","type":"BoxAnnotation"},{"id":"ffd3de92-1e68-417e-a8e3-2fccd64961d0","type":"GlyphRenderer"},{"id":"1b46c9c2-6c71-4ece-9e73-711145a580a3","type":"GlyphRenderer"},{"id":"ffd97e02-a427-47f2-bed5-64f61d21c542","type":"GlyphRenderer"},{"id":"0cdfa5d1-5a93-43b6-957c-c0ec435de61d","type":"GlyphRenderer"},{"id":"c4dc52f8-d966-45fa-bb5a-c1e0d11a76f4","type":"GlyphRenderer"},{"id":"38527dd1-8dc6-4650-b823-49bbea2fc722","type":"Legend"},{"id":"7b1cd4d9-0f01-497d-9fcf-a12c59c83f55","type":"CategoricalAxis"},{"id":"d537e190-0390-4f12-ba99-4f3936ec9abc","type":"LinearAxis"},{"id":"bfa0d6bf-3091-4cc4-8725-af78607250bc","type":"Grid"}],"title":{"id":"dd14bf26-d164-4686-ab48-e6fc9356c697","type":"Title"},"tool_events":{"id":"29192bd1-6c22-4b97-90f3-5597039b51fb","type":"ToolEvents"},"toolbar":{"id":"484e2aac-2536-4022-b322-1b46d3507ed5","type":"Toolbar"},"width":400,"x_mapper_type":"auto","x_range":{"id":"045eff29-8ccf-4aac-bbe7-d5415fd27e14","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"b7d12afc-2a62-4b0f-bd64-dead7ddd49ce","type":"Range1d"}},"id":"1690722f-7399-4d37-8d72-7a0dc7dbf88e","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"cc7fe5c9-6c55-408e-a508-4f08437be968","type":"ColumnDataSource"},"glyph":{"id":"b3a03135-d467-4774-8de2-5792240b7ce4","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0cdfa5d1-5a93-43b6-957c-c0ec435de61d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units" ...

# %%
# Construindo um ScatterPlot
from bokeh.charts import Scatter, output_file, show

# Preparando os dados
from bokeh.sampledata.autompg import autompg as df

# Criando um Scatter Plot
p = Scatter(df, x = 'mpg', y = 'hp', color = 'cyl',
            title = "Consumo x Potência",
            legend = 'top_right',
            xlabel = "Km/Litro",
            ylabel = "Potência do Motor")

# Especificando o arquivo de saída
output_file("Bokeh-Chart-Interativo.html")

# Visualizando o gráfico
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4bb4cc58-7b91-42d8-8d78-2732c69f7cc4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4bb4cc58-7b91-42d8-8d78-2732c69f7cc4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4bb4cc58-7b91-42d8-8d78-2732c69f7cc4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4bb4cc58-7b91-42d8-8d78-2732c69f7cc4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a5d85b02-f4e7-433b-aac9-293470041983":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#00ad9c"},"line_color":{"value":"#00ad9c"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"ac8ca457-a180-4936-a8e6-97b5778fc541","type":"Circle"},{"attributes":{"data_source":{"id":"60a5b6c1-6282-491e-83c5-fa758d36b82e","type":"ColumnDataSource"},"glyph":{"id":"ac8ca457-a180-4936-a8e6-97b5778fc541","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"a7e2b676-7d90-4022-94d0-4212389a19df","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"961a1a9a-4822-4e7d-a6dc-2c2146b7f0e4","type":"BoxAnnotation"},"plot":{"id":"d55142dc-4c0b-4410-be50-18d4a1cde22a","subtype":"Chart","type":"Plot"}},"id":"eaec3c40-a5b0-4a23-9b6a-0d8ac1a0055e","type":"BoxZoomTool"},{"attributes":{},"id":"577bfd69-780b-4432-b12b-13be904cf75e","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"15c7e69f-45e7-4ee6-ad25-ef5ac1c8cb8a","type":"Circle"},{"attributes":{"axis_label":"Pot\u00eancia do Motor","formatter":{"id":"0b259a5f-e644-400f-90b6-3c761c4306eb","type":"BasicTickFormatter"},"plot":{"id":"d55142dc-4c0b-4410-be50-18d4a1cde22a","subtype":"Chart","type":"Plot"},"ticker":{"id":"e381740e-06d2-4bb3-bf9e-ca361a91d58a","type":"BasicTicker"}},"id":"cd264027-d67e-43a9-bcb9-9248785ea1bc","type":"LinearAxis"},{"attributes":{"label":{"value":"5"},"renderers":[{"id":"d6cd6b08-2655-4c8d-8e9f-6c8dfec449b1","type":"GlyphRenderer"}]},"id":"29b89530-2269-45ec-99ff-1752c346ce60","type":"LegendItem"},{"attributes":{"plot":{"id":"d55142dc-4c0b-4410-be50-18d4a1cde22a","subtype":"Chart","type":"Plot"}},"id":"80202bf5-163b-4cb3-8b5a-0ebad78085f0","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d32b7985-fadf-4221-bb8c-aefe51aed1fe","type":"Circle"},{"attributes":{"data_source":{"id":"1f10e61d-d754-4dce-af94-0897c79dda18","type":"ColumnDataSource"},"glyph":{"id":"d32b7985-fadf-4221-bb8c-aefe51aed1fe","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"223e2ee9-45d7-4123-af8c-f773573728c6","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d55142dc-4c0b-4410-be50-18d4a1cde22a","subtype":"Chart","type":"Plot"}},"id":"8efef2d7-6761-44e7-94fa-037176d75fb8","type":"SaveTool"},{"attributes":{"label":{"value":"4"},"renderers":[{"id":"223e2ee9-45d7-4123-af8c-f773573728c6","type":"GlyphRenderer"}]},"id":"de000c46-9582-4136-b644-ba7eb6cb1f7c","type":"LegendItem"},{"attributes":{"label":{"value":"3"},"renderers":[{"id":"448198e6-e75a-4ae3-92b9-cb66b96a0b5c","type":"GlyphRenderer"}]},"id":"37d4fe23-8e6c-4ad4-8f32-6a701521a3ee","type":"LegendItem"},{"attributes":{},"id":"e381740e-06d2-4bb3-bf9e-ca361a91d58a","type":"BasicTicker"},{"attributes":{"callback":null,"end":248.4,"start":27.599999999999998},"id":"b300e131-bd78-4e15-a4fe-3a170b8e2488","type":"Range1d"},{"attributes":{"plot":{"id":"d55142dc-4c0b-4410-be50-18d4a1cde22a","subtype":"Chart","type":"Plot"}},"id":"b72c7893-6f9f-4f63-8c1f-173701d2c568","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"cyl":3},{"cyl":3},{"cyl":3},{"cyl":3}],"cyl":[3,3,3,3],"x_values":{"__ndarray__":"AAAAAAAAM0AAAAAAAAAyQAAAAAAAgDVAMzMzMzOzN0A=","dtype":"float64","shape":[4]},"y_values":[97,90,110,100]}},"id":"e2f76df0-4643-4256-a47d-2ad0f4f7992b","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{"cyl":4},{ ...

# %%
# Criando Violin Plots - Seaborn e Bokeh
import seaborn as sea

from bokeh import mpl
from bokeh.plotting import output_file, show

tips = sea.load_dataset("tips")

sea.set_style("whitegrid")

ax = sea.violinplot(x = "day", y = "total_bill", hue = "sex", data = tips, 
                    palette = "Set2", split = True, 
                    scale = "count", inner = "stick")

output_file("Bokeh-ViolinPlot.html")

show(mpl.to_bokeh())
# Out:
# /Users/dmpm/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: MPL compatibility can no longer be successfully maintained, and is now deprecated. All MPL compat functions will be removed completely on the release of Bokeh 1.0. See http://bokeh.pydata.org/en/latest/docs/releases/0.12.5.html for more information
#   warn(message)
# /Users/dmpm/anaconda/lib/python3.6/site-packages/bokeh/core/compat/bokeh_renderer.py:252: UserWarning: Path drawing has performance issues, please use mpl PathCollection instead
#   warnings.warn("Path drawing has performance issues, please use mpl PathCollection instead")
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="262225e5-3c5f-4e04-b3c2-40e798b48d00"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("262225e5-3c5f-4e04-b3c2-40e798b48d00");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("262225e5-3c5f-4e04-b3c2-40e798b48d00");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '262225e5-3c5f-4e04-b3c2-40e798b48d00' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8aba7508-4186-4665-b4fa-5b4617cdc687":{"roots":{"references":[{"attributes":{"data_source":{"id":"bd304956-b65a-47ab-b879-0e096a9c3986","type":"ColumnDataSource"},"glyph":{"id":"2751ef9f-4302-44f2-8bbd-6b73762a8e7f","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"a4727313-20ca-4f04-949f-be54039e3500","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["Series 0","Series 1"],"data":{"Series 0":{"__ndarray__":"okW28/3UBEAAAAAAAAAIQA==","dtype":"float64","shape":[2]},"Series 1":{"__ndarray__":"rkfhehRuMkCuR+F6FG4yQA==","dtype":"float64","shape":[2]}}},"id":"01f2ca4a-5c09-4de7-b8cd-695f389d3e89","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#595959"},"line_width":{"value":0.875},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"09e43162-5990-4eac-8c92-428c50fe9713","type":"Line"},{"attributes":{"line_color":{"value":"#595959"},"line_width":{"value":0.875},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"ca754bf6-1ef9-4e92-b75f-2e8a9b9e036b","type":"Line"},{"attributes":{"data_source":{"id":"1c0ccec7-be4f-4d75-9626-846279ee0bd6","type":"ColumnDataSource"},"glyph":{"id":"25d8a100-1522-46df-814a-c296d6ea38fb","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"b254683a-635e-416a-b890-89f6a939c71e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"48ad32e6-f339-4d49-ab3a-6cbe311538d3","type":"ColumnDataSource"},"glyph":{"id":"c89f3366-3161-4caa-a194-02eb01d5a89b","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"56ad33ee-c064-4435-897a-bd03c9b1e254","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#595959"},"line_width":{"value":0.875},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"d208879e-dea8-4260-b09b-43afeb9426c9","type":"Line"},{"attributes":{"callback":null,"column_names":["Series 0","Series 1"],"data":{"Series 0":{"__ndarray__":"0zOzcfdf/z8AAAAAAAAAQA==","dtype":"float64","shape":[2]},"Series 1":{"__ndarray__":"CtejcD0qSEAK16NwPSpIQA==","dtype":"float64","shape":[2]}}},"id":"401ce079-01a9-4639-a23e-9e955e83b433","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#595959"},"line_width":{"value":0.875},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"389bbe09-df8e-4b23-85c4-fb411c45859e","type":"Line"},{"attributes":{"data_source":{"id":"401ce079-01a9-4639-a23e-9e955e83b433","type":"ColumnDataSource"},"glyph":{"id":"08d3fcca-7779-495b-8bf2-305681d9b2a7","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"145216b3-d688-4ff3-b157-9bf9c01efa29","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#595959"},"line_width":{"value":0.875},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"fd0f5f75-8bfe-44b6-bea4-2ad1a233433d","type":"Line"},{"attributes":{"line_color":{"value":"#595959"},"line_width":{"value":0.875},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"c4955c6f-5bde-4219-b919-419f6184f9ca","type":"Line"},{"attributes":{"line_color":{"value":"#595959"},"line_width":{"value":0.875},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"574eedb9-f000-4a17-885e-986c22210eeb","type":"Line"},{"attributes":{"callback":null,"column_names":["Series 0","Series 1"],"data":{"Series 0":{"__ndarray__":"AAAAAAAAAECP6jU46D8AQA==","dtype":"float64","shape":[2]},"Series 1":{"__ndarray__":"CtejcD3qQUAK16NwPepBQA==","dtype":"float64","shape":[2]}}},"id":"fc7a5ed3-172a-460c-948d-b74552de1155","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["Series 0","Series 1"],"data":{"Series 0":{"__ndarray__":"1+Bp/RzvBkAAAAAAAAAIQA==","dtype":"float64","shape":[2]},"Series 1":{"__ndarray__":"MzMzMzNTQUAzMzMzM1NBQA==","dtype":"float64","shape":[2]}}},"id":"e3a3f87a-cf8b-4f1c-bf81-10b8de51ec17","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fc7a5ed3-172a-460c-948d-b74552de1155","type":"ColumnDataSource"},"glyph":{"id":"fd0f5f75-8bfe-44b6-bea4-2ad1a233433d","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"43796 ...

# %%
# Gráficos de Linha
from bokeh.plotting import figure, output_file, show

# Outuput
output_file("Bokeh-Grafico-Linha.html")

p = figure(plot_width = 400, plot_height = 400)

# Adicionando círculos ao gráfico
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size = 20, color = "navy", alpha = 0.5)

# Mostrando o resultado
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="df38df34-c899-4120-9d2d-dfe01acb2c31"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("df38df34-c899-4120-9d2d-dfe01acb2c31");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("df38df34-c899-4120-9d2d-dfe01acb2c31");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'df38df34-c899-4120-9d2d-dfe01acb2c31' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"66e55dd6-1403-4ab3-aa9e-af2ffbb966fb":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cb5406ba-2932-4fa1-809b-2d1a06f107a1","type":"BoxAnnotation"},{"attributes":{},"id":"5e1f38d2-fa03-4ec7-ae74-78a38b62f34a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"ba209aea-ac8a-4793-95b1-09b4266be32c","type":"LinearAxis"}],"left":[{"id":"960ec47d-d342-4464-94a3-74cafd6a63e2","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"ba209aea-ac8a-4793-95b1-09b4266be32c","type":"LinearAxis"},{"id":"6d1272a6-6db2-4033-ae97-9a27bdb4053f","type":"Grid"},{"id":"960ec47d-d342-4464-94a3-74cafd6a63e2","type":"LinearAxis"},{"id":"cef8cf74-46e2-44a5-9be2-a820d81a0c08","type":"Grid"},{"id":"cb5406ba-2932-4fa1-809b-2d1a06f107a1","type":"BoxAnnotation"},{"id":"46b74227-f683-421e-b41c-d040692a9c6b","type":"GlyphRenderer"}],"title":{"id":"b98050cc-1d7d-4b36-847a-b60a6ae11a90","type":"Title"},"tool_events":{"id":"0c77d64d-b015-49f4-829c-6e97b800b18f","type":"ToolEvents"},"toolbar":{"id":"aba228db-c72f-4046-9967-931965741139","type":"Toolbar"},"x_range":{"id":"c0916e5a-bf3c-4346-8c16-ec111099fb16","type":"DataRange1d"},"y_range":{"id":"1e3353f0-770d-415a-99cf-dc0887509d51","type":"DataRange1d"}},"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f8cdd635-6bdc-4540-924a-5da69152af64","type":"BasicTicker"}},"id":"6d1272a6-6db2-4033-ae97-9a27bdb4053f","type":"Grid"},{"attributes":{"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"}},"id":"1782996d-8124-4d97-9635-aad0f6541682","type":"PanTool"},{"attributes":{"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"}},"id":"922b0cd2-152f-43aa-b83b-e6873e7a1976","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"}},"id":"52baa86e-acd3-4763-abeb-70c58a478d81","type":"ResetTool"},{"attributes":{"callback":null},"id":"c0916e5a-bf3c-4346-8c16-ec111099fb16","type":"DataRange1d"},{"attributes":{},"id":"f8cdd635-6bdc-4540-924a-5da69152af64","type":"BasicTicker"},{"attributes":{"overlay":{"id":"cb5406ba-2932-4fa1-809b-2d1a06f107a1","type":"BoxAnnotation"},"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"}},"id":"d5d8dc32-2c4d-47f8-b97b-e44e64e94d83","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"}},"id":"991c8b82-d86a-4399-9b28-ae1455489a6e","type":"SaveTool"},{"attributes":{},"id":"07ec0ea6-4a22-4d9f-ad77-f94381dd3051","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"5e1f38d2-fa03-4ec7-ae74-78a38b62f34a","type":"BasicTickFormatter"},"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"954c905d-3479-4675-96d7-0027b4b5853e","type":"BasicTicker"}},"id":"960ec47d-d342-4464-94a3-74cafd6a63e2","type":"LinearAxis"},{"attributes":{},"id":"954c905d-3479-4675-96d7-0027b4b5853e","type":"BasicTicker"},{"attributes":{"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"}},"id":"a744095d-2e3f-4189-a6cb-dd7df6062b8a","type":"HelpTool"},{"attributes":{},"id":"0c77d64d-b015-49f4-829c-6e97b800b18f","type":"ToolEvents"},{"attributes":{"formatter":{"id":"07ec0ea6-4a22-4d9f-ad77-f94381dd3051","type":"BasicTickFormatter"},"plot":{"id":"5a0c40e4-c1d7-420a-b6c2-5dd5009bb6b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f8cdd635-6bdc-4540-924a-5da69152af64","type":"BasicTicker"}},"id":"ba209aea-ac8a-4793-95b ...

# %%
# Geojson
from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson

geo_source = GeoJSONDataSource(geojson=geojson)

p = figure()
p.circle(x = 'x', y = 'y', alpha = 0.9, source = geo_source)
output_file("Bokeh-GeoJSON.html")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="24932722-a76c-4519-9b12-af8e3d64d171"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("24932722-a76c-4519-9b12-af8e3d64d171");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("24932722-a76c-4519-9b12-af8e3d64d171");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '24932722-a76c-4519-9b12-af8e3d64d171' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"691dd749-2f25-4303-89c6-a47596bf8034":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.9},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b9d42248-ecbb-46ad-8c12-301786850a11","type":"Circle"},{"attributes":{"formatter":{"id":"a9cb154d-667a-4313-b17c-1d73425df9c9","type":"BasicTickFormatter"},"plot":{"id":"1f792091-70f3-4eb7-bcf8-7a8a630ad3d3","subtype":"Figure","type":"Plot"},"ticker":{"id":"dceeab77-fbb1-4680-9949-6d4635018c84","type":"BasicTicker"}},"id":"4bc78a55-cd72-4655-a1c8-fedda47bbf01","type":"LinearAxis"},{"attributes":{"below":[{"id":"b59c8bb1-3b97-43c3-b64f-fef3283544be","type":"LinearAxis"}],"left":[{"id":"4bc78a55-cd72-4655-a1c8-fedda47bbf01","type":"LinearAxis"}],"renderers":[{"id":"b59c8bb1-3b97-43c3-b64f-fef3283544be","type":"LinearAxis"},{"id":"71c10b63-0900-4bd2-b7f9-48efe5166319","type":"Grid"},{"id":"4bc78a55-cd72-4655-a1c8-fedda47bbf01","type":"LinearAxis"},{"id":"0b862025-1d89-4c0a-81dc-355c64a174bc","type":"Grid"},{"id":"9164e44f-6309-4460-9265-392de782bee3","type":"BoxAnnotation"},{"id":"0b4d1d6d-fac6-4028-9b90-e0db338809c1","type":"GlyphRenderer"}],"title":{"id":"a9e6d2da-c801-483e-935e-1f8611b339de","type":"Title"},"tool_events":{"id":"cf24ae30-404a-4389-8ff3-414caa0aafc3","type":"ToolEvents"},"toolbar":{"id":"7ca9c6ef-0647-4915-b9be-5ac251876a5c","type":"Toolbar"},"x_range":{"id":"37a7b62b-44f1-4304-86e5-89c1c712b672","type":"DataRange1d"},"y_range":{"id":"d9065bdc-9fa5-4741-9e60-acce4650f8fd","type":"DataRange1d"}},"id":"1f792091-70f3-4eb7-bcf8-7a8a630ad3d3","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"d9065bdc-9fa5-4741-9e60-acce4650f8fd","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"52e54d39-1663-406e-a699-5938ea06ba8b","type":"PanTool"},{"id":"76de95c3-a057-4fba-9e5f-1f3afbd067bb","type":"WheelZoomTool"},{"id":"35e59c8e-b2b9-433e-998d-3ee2b83490f0","type":"BoxZoomTool"},{"id":"7ec22854-2a8a-4f42-a6cc-3d74bbd218db","type":"SaveTool"},{"id":"4626e9fc-04b6-4cf2-b024-b1682b6b5d3d","type":"ResetTool"},{"id":"e5e9f3be-4de8-4c24-bbe5-81a6b2d61700","type":"HelpTool"}]},"id":"7ca9c6ef-0647-4915-b9be-5ac251876a5c","type":"Toolbar"},{"attributes":{},"id":"dceeab77-fbb1-4680-9949-6d4635018c84","type":"BasicTicker"},{"attributes":{"plot":{"id":"1f792091-70f3-4eb7-bcf8-7a8a630ad3d3","subtype":"Figure","type":"Plot"}},"id":"52e54d39-1663-406e-a699-5938ea06ba8b","type":"PanTool"},{"attributes":{"callback":null},"id":"37a7b62b-44f1-4304-86e5-89c1c712b672","type":"DataRange1d"},{"attributes":{"overlay":{"id":"9164e44f-6309-4460-9265-392de782bee3","type":"BoxAnnotation"},"plot":{"id":"1f792091-70f3-4eb7-bcf8-7a8a630ad3d3","subtype":"Figure","type":"Plot"}},"id":"35e59c8e-b2b9-433e-998d-3ee2b83490f0","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"1f792091-70f3-4eb7-bcf8-7a8a630ad3d3","subtype":"Figure","type":"Plot"},"ticker":{"id":"9af066c8-a8ae-4868-aced-cb68cc304cf4","type":"BasicTicker"}},"id":"71c10b63-0900-4bd2-b7f9-48efe5166319","type":"Grid"},{"attributes":{"formatter":{"id":"dee06c6d-8089-46bd-a5ef-d25f25a9ac16","type":"BasicTickFormatter"},"plot":{"id":"1f792091-70f3-4eb7-bcf8-7a8a630ad3d3","subtype":"Figure","type":"Plot"},"ticker":{"id":"9af066c8-a8ae-4868-aced-cb68cc304cf4","type":"BasicTicker"}},"id":"b59c8bb1-3b97-43c3-b64f-fef3283544be","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"a9e6d2da-c801-483e-935e-1f8611b339de","type":"Title"},{"attributes":{},"id":"dee06c6d-8089-46bd-a5ef-d25f25a9ac16","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"1f792091-70f3-4eb7-bcf8-7a8a630ad3d3","subtype":"Figure","type":"Plot"}},"id":"4626e9fc-04b6-4cf2-b024-b1682b6b5d3d","type":"ResetTool"},{"attributes":{"callback":null,"geojson":"{\"type\":\"FeatureCollection\",\"features\":[{\"type\":\"Feature\",\"id\":\"463098\",\"geometry\":{\"type\":\"Point\",\"coor ...

# %%
# Plots de Séries Temporais com Pandas
import pandas as pd
from bokeh.plotting import figure, output_file, show

AAPL = pd.read_csv(
        "http://ichart.yahoo.com/table.csv?s=AAPL&a=0&b=1&c=2000&d=0&e=1&f=2010",
        parse_dates=['Date']
    )

output_file("Bokeh-Datetime.html")

# create a new plot with a datetime axis type
p = figure(width=800, height=250, x_axis_type="datetime")

p.line(AAPL['Date'], AAPL['Close'], color='navy', alpha=0.5)

show(p)

# %%
# Google Maps
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)

map_options = GMapOptions(lat=-23.5431786, lng=-46.62918450000001, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, title="São Paulo"
)

source = ColumnDataSource(
    data=dict(
        lat=[-23.54, -46.62],
        lon=[97.70, 97.74],
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
output_file("gmap_plot.html")
show(plot)

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href=http://facebook.com/dsacademy>facebook.com/dsacademybr</a>
